# %% [markdown]
# ## Building a Database of Performances
#
# This one is likely to get a bit more complex.

# %%
import pandas

# %%
anno_df = pandas.read_json('../data/transcriptions.gz', compression='gzip')
anno_df.head()
# Out:
#                                                    body               created  \
# 0     [{u'type': u'TextualBody', u'purpose': u'descr...  2018-05-30T18:29:57Z
# 10    [{u'type': u'TextualBody', u'purpose': u'descr...  2018-05-30T18:36:33Z
# 1009  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-03T21:42:23Z
# 101   [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:39:55Z
# 1019  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-03T21:42:23Z
#
#       creator             generated  \
# 0         NaN  2018-06-04T09:43:56Z
# 10        NaN  2018-06-04T09:43:56Z
# 1009      NaN  2018-06-04T09:43:57Z
# 101       NaN  2018-06-04T09:43:56Z
# 1019      NaN  2018-06-04T09:43:57Z
#
#                                               generator  \
# 0     [{u'homepage': u'https://www.libcrowds.com', u...
# 10    [{u'homepage': u'https://www.libcrowds.com', u...
# 1009  [{u'homepage': u'https://www.libcrowds.com', u...
# 101   [{u'homepage': u'https://www.libcrowds.com', u...
# 1019  [{u'homepage': u'https://www.libcrowds.com', u...
#
#                                                      id  motivation  \
# 0     https://annotations.libcrowds.com/annotations/...  describing
# 10    https://annotations.libcrowds.com/annotations/...  describing
# 1009  https://annotations.libcrowds.com/annotations/...  describing
# 101   https://annotations.libcrowds.com/annotations/...  describing
# 1019  https://annotations.libcrowds.com/annotations/...  describing
#
#                                                  partOf    tag  \
# 0     https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
# 10    https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
# 1009  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
# 101   https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  title
# 1019  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
#
#                                                  target  \
# 0     https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 10    https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 1009  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 101   {u'source': u'https://api.bl.uk/metadata/iiif/...
# 1019  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
#
#                       transcription        type
# 0                        Melo-Drama  Annotation
# 10    Asiatic Melo-Dramatic Romance  Annotation
# 1009                         Comedy  Annotation
# 101              Othello Travestie   Annotation
# 1019                         Comedy  Annotation

# %%
task_df = pandas.read_json('../data/pybossa_tasks.gz', compression='gzip')

# %%
def get_task_id(generator):
    for g in generator:
        if 'api/task' in g['id']:
            return g['id'].split('/')[-1]

# %%
anno_df['task_id'] = anno_df['generator'].apply(get_task_id)
anno_df.head()
# Out:
#                                                    body               created  \
# 0     [{u'type': u'TextualBody', u'purpose': u'descr...  2018-05-30T18:29:57Z
# 10    [{u'type': u'TextualBody', u'purpose': u'descr...  2018-05-30T18:36:33Z
# 1009  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-03T21:42:23Z
# 101   [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:39:55Z
# 1019  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-03T21:42:23Z
#
#       creator             generated  \
# 0         NaN  2018-06-04T09:43:56Z
# 10        NaN  2018-06-04T09:43:56Z
# 1009      NaN  2018-06-04T09:43:57Z
# 101       NaN  2018-06-04T09:43:56Z
# 1019      NaN  2018-06-04T09:43:57Z
#
#                                               generator  \
# 0     [{u'homepage': u'https://www.libcrowds.com', u...
# 10    [{u'homepage': u'https://www.libcrowds.com', u...
# 1009  [{u'homepage': u'https://www.libcrowds.com', u...
# 101   [{u'homepage': u'https://www.libcrowds.com', u...
# 1019  [{u'homepage': u'https://www.libcrowds.com', u...
#
#                                                      id  motivation  \
# 0     https://annotations.libcrowds.com/annotations/...  describing
# 10    https://annotations.libcrowds.com/annotations/...  describing
# 1009  https://annotations.libcrowds.com/annotations/...  describing
# 101   https://annotations.libcrowds.com/annotations/...  describing
# 1019  https://annotations.libcrowds.com/annotations/...  describing
#
#                                                  partOf    tag  \
# 0     https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
# 10    https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
# 1009  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
# 101   https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  title
# 1019  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  genre
#
#                                                  target  \
# 0     https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 10    https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 1009  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 101   {u'source': u'https://api.bl.uk/metadata/iiif/...
# 1019  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
#
#                       transcription        type task_id
# 0                        Melo-Drama  Annotation   78482
# 10    Asiatic Melo-Dramatic Romance  Annotation   78801
# 1009                         Comedy  Annotation   76071
# 101              Othello Travestie   Annotation   77426
# 1019                         Comedy  Annotation   76075

# %% [markdown]
# ## Add source column
#
# This is needed to later find our links between different types of annotation

# %%
def get_source(target):
    if isinstance(target, dict):
        return target['source']
    else:
        return target

# %%
anno_df['source'] = anno_df['target'].apply(get_source)

# %% [markdown]
# ## Map titles
#
# Start with the titles, as these will be our root element.

# %%
def get_tag_df(tag):
    tag_df = anno_df[anno_df['tag'] == tag]
    tag_df = tag_df.rename(columns={'transcription': tag})
    tag_df = tag_df.drop('tag', axis=1)
    return tag_df

# %% [markdown]
# This becomes our main dataframe

# %%
df = get_tag_df('title')
df.head()
# Out:
#                                                   body               created  \
# 101  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:39:55Z
# 102  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:40:38Z
# 103  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:42:59Z
# 104  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:44:28Z
# 105  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:44:49Z
#
#      creator             generated  \
# 101      NaN  2018-06-04T09:43:56Z
# 102      NaN  2018-06-04T09:43:56Z
# 103      NaN  2018-06-04T09:43:56Z
# 104      NaN  2018-06-04T09:43:56Z
# 105      NaN  2018-06-04T09:43:56Z
#
#                                              generator  \
# 101  [{u'homepage': u'https://www.libcrowds.com', u...
# 102  [{u'homepage': u'https://www.libcrowds.com', u...
# 103  [{u'homepage': u'https://www.libcrowds.com', u...
# 104  [{u'homepage': u'https://www.libcrowds.com', u...
# 105  [{u'homepage': u'https://www.libcrowds.com', u...
#
#                                                     id  motivation  \
# 101  https://annotations.libcrowds.com/annotations/...  describing
# 102  https://annotations.libcrowds.com/annotations/...  describing
# 103  https://annotations.libcrowds.com/annotations/...  describing
# 104  https://annotations.libcrowds.com/annotations/...  describing
# 105  https://annotations.libcrowds.com/annotations/...  describing
#
#                                                 partOf  \
# 101  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 102  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 103  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 104  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 105  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
#
#                                                 target  \
# 101  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 102  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 103  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 104  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 105  {u'source': u'https://api.bl.uk/metadata/iiif/...
#
#                                        title        type task_id  \
# 101                       Othello Travestie   Annotation   77426
# 102            Revenge; Or, the Captive Moor  Annotation   77430
# 103  Jew of Lubeck Or, the Heart of a Father  Annotation   74944
# 104        Night Hag Or, St. Swithin's Chair  Annotation   75378
# 105                            Woodman's Hut  Annotation   75396
#
#                                                 source
# 101  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 102  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 103  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 104  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 105  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...

# %% [markdown]
# ## Map dates

# %%
dates_df = get_tag_df('date')

# %%
cols = ['date', 'source', 'task_id']
df = df.merge(dates_df[cols], on='source', how='left', suffixes=('_title', '_date'))
df.head()
# Out:
#                                                 body               created  \
# 0  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:39:55Z
# 1  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:40:38Z
# 2  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:42:59Z
# 3  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:44:28Z
# 4  [{u'type': u'TextualBody', u'purpose': u'descr...  2018-06-01T16:44:49Z
#
#    creator             generated  \
# 0      NaN  2018-06-04T09:43:56Z
# 1      NaN  2018-06-04T09:43:56Z
# 2      NaN  2018-06-04T09:43:56Z
# 3      NaN  2018-06-04T09:43:56Z
# 4      NaN  2018-06-04T09:43:56Z
#
#                                            generator  \
# 0  [{u'homepage': u'https://www.libcrowds.com', u...
# 1  [{u'homepage': u'https://www.libcrowds.com', u...
# 2  [{u'homepage': u'https://www.libcrowds.com', u...
# 3  [{u'homepage': u'https://www.libcrowds.com', u...
# 4  [{u'homepage': u'https://www.libcrowds.com', u...
#
#                                                   id  motivation  \
# 0  https://annotations.libcrowds.com/annotations/...  describing
# 1  https://annotations.libcrowds.com/annotations/...  describing
# 2  https://annotations.libcrowds.com/annotations/...  describing
# 3  https://annotations.libcrowds.com/annotations/...  describing
# 4  https://annotations.libcrowds.com/annotations/...  describing
#
#                                               partOf  \
# 0  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 1  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 2  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 3  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 4  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
#
#                                               target  \
# 0  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 1  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 2  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 3  {u'source': u'https://api.bl.uk/metadata/iiif/...
# 4  {u'source': u'https://api.bl.uk/metadata/iiif/...
#
#                                      title        type task_id_title  \
# 0                       Othello Travestie   Annotation         77426
# 1            Revenge; Or, the Captive Moor  Annotation         77430
# 2  Jew of Lubeck Or, the Heart of a Father  Annotation         74944
# 3        Night Hag Or, St. Swithin's Chair  Annotation         75378
# 4                            Woodman's Hut  Annotation         75396
#
#                                               source        date task_id_date
# 0  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  1836-12-08        83095
# 1  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  1850-10-11        83096
# 2  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  1828-04-11        82838
# 3  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  1828-01-29        82997
# 4  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...  1830-11-09        83004

# %% [markdown]
# We now have titles mapped against dates

# %%
df[['title', 'date']].head()
# Out:
#                                      title        date
# 0                       Othello Travestie   1836-12-08
# 1            Revenge; Or, the Captive Moor  1850-10-11
# 2  Jew of Lubeck Or, the Heart of a Father  1828-04-11
# 3        Night Hag Or, St. Swithin's Chair  1828-01-29
# 4                            Woodman's Hut  1830-11-09

# %% [markdown]
# ## Mapping the genres
#
# Mapping the genres requires us to go back to the PYBOSSA task that was used to create each transcription. We have a match if the target of a genre task is the same as the target of a title annotation.

# %%
genres_df = get_tag_df('genre')

# %%
def map_fragment_from_task(task_id):
    try:
        task = task_df.loc[int(task_id)]
    except KeyError:
        return None
    
    return task['info']['target']['selector']['value']

# %%
genres_df['fragment'] = genres_df['task_id'].apply(map_fragment_from_task)
df['fragment'] = df['task_id_title'].apply(map_fragment_from_task)

# %% [markdown]
# We can't merge on the target easily because dictionary columns are not hashable, so create another lookup function.

# %%
cols = ['genre', 'source', 'fragment']
df = df.merge(genres_df[cols], on=['source', 'fragment'], how='left')

# %% [markdown]
# ## Add a link back to the original image
#
# Again, using the task ID.

# %%
def map_link_from_task(task_id):
    try:
        task = task_df.loc[int(task_id)]
    except KeyError:
        return None
    
    return task['info']['link']

# %%
df['link'] = df['task_id_title'].apply(map_link_from_task)

# %%
df = df[['partOf', 'source', 'title', 'date', 'genre', 'link']]
df.head()
# Out:
#                                               partOf  \
# 0  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 1  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 2  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 3  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 4  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
#
#                                               source  \
# 0  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 1  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 2  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 3  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
# 4  https://api.bl.uk/metadata/iiif/ark:/81055/vdc...
#
#                                      title        date              genre  \
# 0                       Othello Travestie   1836-12-08           Burletta
# 1            Revenge; Or, the Captive Moor  1850-10-11  Classical Tragedy
# 2  Jew of Lubeck Or, the Heart of a Father  1828-04-11        After-Piece
# 3        Night Hag Or, St. Swithin's Chair  1828-01-29                NaN
# 4                            Woodman's Hut  1830-11-09                NaN
#
#                                                 link
# 0  http://access.bl.uk/item/viewer/ark:/81055/vdc...
# 1  http://access.bl.uk/item/viewer/ark:/81055/vdc...
# 2  http://access.bl.uk/item/viewer/ark:/81055/vdc...
# 3  http://access.bl.uk/item/viewer/ark:/81055/vdc...
# 4  http://access.bl.uk/item/viewer/ark:/81055/vdc...

# %% [markdown]
# ## Map volume metadata

# %%
volume_md_df = pandas.read_csv('../metadata/volume.csv')
volume_md_df.set_index('manifest_uri', inplace=True, verify_integrity=True)

# %%
cols = ['theatre', 'city', 'country']
df = df.merge(volume_md_df[cols], left_on='partOf', right_on='manifest_uri', how='left')

# %%
df.to_csv('../data/performances.csv', encoding='utf-8', index=False)

# %% [markdown]
# pybossa_tasks_df = pandas.read_pickle('../data/pybossa_tasks.pkl')
